# %% [markdown]
# <a href="https://colab.research.google.com/github/ArveySuarez/ModelosAnaliticosUnicafam202607/blob/main/Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 3

# %%
suma=a+b

# %%
# suma
suma = a + b
print(suma)
# Out:
# 13

# %%
# resta
resta = a - b
print(resta)
# Out:
# 7

# %%
# multiplicacion
multiplicacion = a * b
print(multiplicacion)
# Out:
# 30

# %%
# división
division = a / b
print(division)
# Out:
# 3.3333333333333335

# %%
# modulo
modulo = a % b
print(modulo)
# Out:
# 1

# %%
# Potencia
potencia = a ** b
print(potencia)
# Out:
# 1000

# %%
# División
division_entera = a // b
print(division_entera)
# Out:
# 3

# %%
# División entera
division_entera = a // b
print(division_entera)
# Out:
# 3

# %%
cadena="python es genial"
print(cadena[5])
# Out:
# n

# %%
# extraer la palabra python
print(cadena[0:6])
# Out:
# python

# %%
# extraer la palabra python
print(cadena[0:18])
# Out:
# python es genial

# %%
# extraer la palabra python
print(cadena[10:16])
# Out:
# genial

# %%
# concatenar valores
palabra1="hola"
palabra2="mundo"
print(palabra1+","+palabra2)
# Out:
# hola,mundo

# %%
# cambios de formato
print(cadena.upper())
# Out:
# PYTHON ES GENIAL

# %%
# cambios de formato
print(cadena.lower())
# Out:
# python es genial
