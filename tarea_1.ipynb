# %% [markdown]
# <a href="https://colab.research.google.com/github/ArveySuarez/ModelosAnaliticosUnicafam202607/blob/main/tarea_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola, mundo!"

# %%
print(saludo[0])
# Out:
# H

# %%
print(saludo[6:11])
# Out:
# mundo

# %%
saludo_completo = saludo + ", ¿cómo estás?"

# %%
print(saludo_completo)
# Out:
# Hola, mundo!, ¿cómo estás?

# %%
print(saludo_completo.upper())
# Out:
# HOLA, MUNDO!, ¿CÓMO ESTÁS?

# %%
print(saludo_completo.lower())
# Out:
# hola, mundo!, ¿cómo estás?

# %%
saludo_reemplazo = saludo_completo.replace("mundo", "Python", 1)

# %%
print(saludo_reemplazo)
# Out:
# Hola, Python!, ¿cómo estás?
